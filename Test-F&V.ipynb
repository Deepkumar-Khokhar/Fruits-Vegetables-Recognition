# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
cnn = tf.keras.models.load_model('trained_model.h5')

# %%
import cv2

# %%
image_path = r'C:\Users\Lenovo\Desktop\F&V\test\banana\Image_1.jpg'

# %%
img = cv2.imread(image_path)
plt.imshow(img)
plt.title('test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image = tf.keras.preprocessing.image.load_img(image_path,target_size=(64,64))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
input_arr = np.array([input_arr])
predictions = cnn.predict(input_arr)
# Out:
# 1/1 [==============================] - 0s 47ms/step

# %%
print(predictions)
# Out:
# [[1.06736962e-07 9.93572116e-01 3.02070191e-07 1.18011872e-06
#   2.36057599e-06 1.63588447e-06 1.99805745e-05 5.77326173e-05
#   7.93566528e-08 5.04797936e-06 1.83843963e-06 1.04739737e-08
#   1.23195816e-04 5.11856456e-07 1.64029306e-08 9.51172012e-07
#   2.49982008e-06 2.10852348e-04 1.20335312e-06 5.81137174e-05
#   7.48268114e-10 1.18525240e-05 1.37472108e-11 1.19367842e-05
#   2.06443133e-07 5.65051800e-03 1.14321020e-12 3.99949613e-06
#   1.37487281e-04 1.07013962e-04 8.98775215e-06 2.76525202e-06
#   5.12929699e-10 1.15935976e-10 5.40430983e-06 1.19338011e-07]]

# %%
validation_set = tf.keras.utils.image_dataset_from_directory(
    r'C:\Users\Lenovo\Desktop\F&V\test',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(64, 64),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False,
)
# Out:
# Found 359 files belonging to 36 classes.

# %%
result_index = np.where(predictions[0]==max(predictions[0]))
print(result_index)
# Out:
# (array([1], dtype=int64),)

# %%
validation_set.class_names
# Out:
# ['apple',
#  'banana',
#  'beetroot',
#  'bell pepper',
#  'cabbage',
#  'capsicum',
#  'carrot',
#  'cauliflower',
#  'chilli pepper',
#  'corn',
#  'cucumber',
#  'eggplant',
#  'garlic',
#  'ginger',
#  'grapes',
#  'jalepeno',
#  'kiwi',
#  'lemon',
#  'lettuce',
#  'mango',
#  'onion',
#  'orange',
#  'paprika',
#  'pear',
#  'peas',
#  'pineapple',
#  'pomegranate',
#  'potato',
#  'raddish',
#  'soy beans',
#  'spinach',
#  'sweetcorn',
#  'sweetpotato',
#  'tomato',
#  'turnip',
#  'watermelon']

# %%
print("It is a {}".format(validation_set.class_names[result_index[0][0]]))
# Out:
# It is a banana
